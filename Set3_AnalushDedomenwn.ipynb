# %% [markdown]
# ## Gaussian Distribution

# %%
import numpy as np
import random

# %%
sigma=1
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(1000)]
gauss1=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,title=r'Gaussian Distribution with  n=1000, bins=70, σ =1 ',fontsize=15)
show(gauss1,title=r'Gaussian Distribution with  n=1000, bins=70, σ =1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss1.pdf')

# %%
sigma=1.5
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(1000)]
gauss2=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Gaussian Distribution with  n=1000, bins=70, σ =1.5 ')
show(gauss2,title=r'Gaussian Distribution with  n=1000, bins=70, σ =1.5 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss2.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss2.pdf')

# %%
sigma=2.5
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(1000)]
gauss3=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Gaussian Distribution with  n=1000, bins=70, σ =2.5 ')
show(gauss3,title=r'Gaussian Distribution with  n=1000, bins=70, σ =2.5 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss3.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss3.pdf')

# %%
sigma=1
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(10000)]
gauss1=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Gaussian Distribution with  n=10000, bins=70, σ =1 ')
show(gauss1,title=r'Gaussian Distribution with  n=10000, bins=70, σ =1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss4.pdf')

# %%
sigma=1
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(10000)]
gauss1=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Gaussian Distribution with  n=10000, bins=700, σ =1 ')
show(gauss1,title=r'Gaussian Distribution with  n=10000, bins=700, σ =1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss5.pdf')

# %%
sigma=1
T1 = RealDistribution('gaussian', sigma)
S1=[T1.get_random_element() for _ in range(100000)]
gauss1=histogram( S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Gaussian Distribution with  n=100000, bins=700, σ =1 ')
show(gauss1,title=r'Gaussian Distribution with  n=100000, bins=700, σ =1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gauss1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\gauss6.pdf')

# %% [markdown]
# ## Exponential Power Distribution

# %%
a = 1
b = 1
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(1000)]
exp1=histogram( S2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =1, κ=1 ')
show(exp1,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =1, κ=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp1.pdf')

# %%
a = 2
b = 2.5
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(1000)]
exp2=histogram( S2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =2, κ=2.5 ')
show(exp2,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =2, κ=2.5 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp2.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp2.pdf')

# %%
a = 2
b = 1
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(1000)]
exp3=histogram( S2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =2, κ=1 ')
show(exp3,title=r'Exponential Power Distribution with  n=1000, bins=70, λ =2, κ=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp3.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp3.pdf')

# %%
a = 2
b = 1
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(10000)]
exp4=histogram( S2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=10000, bins=70, λ =2, κ=1 ')
show(exp4,title=r'Exponential Power Distribution with  n=10000, bins=70, λ =2, κ=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp4.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp4.pdf')

# %%
a = 2
b = 1
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(10000)]
exp5=histogram( S2,bins=700, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=10000, bins=700, λ =2, κ=1 ')
show(exp5,title=r'Exponential Power Distribution with  n=10000, bins=700, λ =2, κ=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp5.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp5.pdf')

# %%
a = 2
b = 1
T2 = RealDistribution('exppow', [a, b])
S2=[T2.get_random_element() for _ in range(100000)]
exp6=histogram( S2,bins=700, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power Distribution with  n=100000, bins=700, λ =2, κ=1 ')
show(exp6,title=r'Exponential Power Distribution with  n=100000, bins=700, λ =2, κ=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exp6.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\exp6.pdf')

# %% [markdown]
# ## Weibull Distribution

# %%
a = 1
b = 1
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(1000)]
weib1=histogram( S3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=1000, bins=70, λ =1, α=1 ')
show(weib1,title=r'Weibull Distribution with  n=1000, bins=70, λ =1, α=1 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib1.pdf')

# %%
a = 2
b = 2
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(1000)]
weib2=histogram( S3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=1000, bins=70, λ =2, α=2 ')
show(weib2,title=r'Weibull Distribution with  n=1000, bins=70, λ =2, α=2 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib2.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib2.pdf')

# %%
a = 2
b = 3
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(1000)]
weib3=histogram( S3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=1000, bins=70, λ =2, α=3 ')
show(weib3,title=r'Weibull Distribution with  n=1000, bins=70, λ =2, α=3 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib3.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib3.pdf')

# %%
a = 2
b = 3
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(10000)]
weib4=histogram( S3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=10000, bins=70, λ =2, α=3 ')
show(weib4,title=r'Weibull Distribution with  n=10000, bins=70, λ =2, α=3 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib4.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib4.pdf')

# %%
a = 2
b = 3
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(10000)]
weib5=histogram( S3,bins=700, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=10000, bins=700, λ =2, α=3 ')
show(weib5,title=r'Weibull Distribution with  n=10000, bins=700, λ =2, α=3 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib5.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib5.pdf')

# %%
a = 2
b = 3
T3 = RealDistribution('weibull', [a, b])
S3=[T3.get_random_element() for _ in range(100000)]
weib6=histogram( S3,bins=700, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull Distribution with  n=10000, bins=700, λ =2, α=3 ')
show(weib6,title=r'Weibull Distribution with  n=10000, bins=700, λ =2, α=3 ')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
weib6.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\weib6.pdf')

# %%
mu=np.mean(S2+S3)
joint1=histogram( S2+S3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power/Weibull Distribution, μ=%f'%mu)
show(joint1,title=r'Exponential Power/Weibull Distribution, μ=%f'%mu)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
len(S2+S3)
# Out:
# 200000

# %%
joint1.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\joint1.pdf')

# %%
mu=np.mean(S2+S1)
joint2=histogram( S2+S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Exponential Power/Gaussian Distribution, μ=%f'%mu)
show(joint2,title=r'Exponential Power/Gaussian Distribution, μ=%f'%mu)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
joint2.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\joint2.pdf')

# %%
mu=np.mean(S3+S1)
joint3=histogram( S3+S1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'Weibull/Gaussian Distribution, μ=%f'%mu)
show(joint3,title=r'Weibull/Gaussian Distribution, μ=%f'%mu)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
joint3.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\joint3.pdf')

# %%
S4=S3+S1

# %%
random.shuffle(S4)

# %%
for i in range(2):
    print(np.mean(random.choices(S4, k=5)))
# Out:
# 1.3110613675004177
# 2.1451188151015748

# %%
means1=[]
for i in range(10):
    means1.append(np.mean(random.choices(S4, k=5)))        
means1hist=histogram(means1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'10 groups of n=5')
show(means1hist,title=r'10 groups of n=5')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means1hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means1hist.pdf')

# %%
means2=[]
for i in range(100):
    means2.append(np.mean(random.choices(S4, k=5)))        
means2hist=histogram(means2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'100 groups of n=5')
show(means2hist,title=r'100 groups of n=5')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means2hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means2hist.pdf')

# %%
means3=[]
for i in range(1000):
    means3.append(np.mean(random.choices(S4, k=5)))        
means3hist=histogram(means3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'1000 groups of n=5')
show(means3hist,title=r'1000 groups of n=5')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means3hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means3hist.pdf')

# %%
means4=[]
for i in range(10000):
    means4.append(np.mean(random.choices(S4, k=5)))        
means4hist=histogram(means4,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'10000 groups of n=5')
show(means4hist,title=r'10000 groups of n=5')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means4hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means4hist.pdf')

# %%
means1=[]
for i in range(10):
    means1.append(np.mean(random.choices(S4, k=5)))        
means1hist=histogram(means1,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'10 groups of n=5')
show(means1hist,title=r'10 groups of n=5')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means1hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means5hist.pdf')

# %%
means2=[]
for i in range(100):
    means2.append(np.mean(random.choices(S4, k=10)))        
means2hist=histogram(means2,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'100 groups of n=10')
show(means2hist,title=r'100 groups of n=10')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means2hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means6hist.pdf')

# %%
means3=[]
for i in range(1000):
    means3.append(np.mean(random.choices(S4, k=20)))        
means3hist=histogram(means3,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'1000 groups of n=20')
show(means3hist,title=r'1000 groups of n=20')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means3hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means7hist.pdf')

# %%
means4=[]
for i in range(10000):
    means4.append(np.mean(random.choices(S4, k=50)))        
means4hist=histogram(means4,bins=70, alpha=0.5,edgecolor='red', fill=True, linestyle='dashed', hatch='s',linewidth=1,fontsize=15,title=r'10000 groups of n=50')

show(means4hist,title=r'10000 groups of n=50')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
means4hist.save(r'G:\desktop\Point of Know Return\ΥΠΟΑΤΟΜΙΚΗΣ\Αναλυση\Σετ3\means8hist.pdf')

# %%
np.mean(means4)
# Out:
# 0.8952162153443103
