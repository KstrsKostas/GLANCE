# %% [markdown]
# # Statistical Mechanics
# ## Exercise 23

# %%
s=[]
for i in range (51):
    s.append(i*0.05)
    

for T in range(1,11):
    f=[]
    for i in range (len(s)):
        f.append(tanh((s[i])*(10/T)))
    graph=list_plot(s,color='red',legend_label='$<s>$', legend_color='red')+list_plot(f,color='blue',legend_label='$tanh(<s> T_c/T)$', legend_color='blue')
    show(graph,xmin=0,xmax=30,title=r'T=%d'%T)
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
